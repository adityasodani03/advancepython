# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasodani03/advancepython/blob/main/pynew7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement - placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.shape
# Out:
# (100, 3)

# %%
x=df.drop(columns=['placed'])
y=df['placed']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("Total data shape : ",df.shape)
print("-------------------------------")
print("-------------------------------")
print("Input data shape : ",x.shape)
print("Input data shape : ",x_train.shape)
print("Input data shape : ",x_test.shape)
print("-------------------------------")
print("-------------------------------")
print("Target data shape : ",y.shape)
print("Target data shape : ",y_train.shape)
print("Target data shape : ",y_test.shape)
# Out:
# Total data shape :  (100, 3)
# -------------------------------
# -------------------------------
# Input data shape :  (100, 2)
# Input data shape :  (80, 2)
# Input data shape :  (20, 2)
# -------------------------------
# -------------------------------
# Target data shape :  (100,)
# Target data shape :  (80,)
# Target data shape :  (20,)

# %%
#df(100,3) = x(100,2)+y(100,1)
#x(100,2) = x_train(80,2)+x_test(20,2)
#y(100,1) = y_train(80,1)+y_test(20,1)

# %% [markdown]
# COVID DATA

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({"Male" : 1 , "Female" : 0})
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60       1  103.0  Mild  Kolkata        No
# 1   27       1  100.0  Mild    Delhi       Yes
# 2   42       1  101.0  Mild    Delhi        No
# 3   31       0   98.0  Mild  Kolkata        No
# 4   65       0  101.0  Mild   Mumbai        No

# %%
df['cough']=df['cough'].map({"Mild" : 0 , "Strong" : 1})
df.sample(4)
# Out:
#     age  gender  fever  cough       city has_covid
# 52   47       0  100.0      1  Bangalore       Yes
# 24   13       0  100.0      1    Kolkata        No
# 75    5       1  102.0      0    Kolkata       Yes
# 21   73       1   98.0      0  Bangalore       Yes

# %%
x=df.drop(columns = ['has_covid'])
y=df['has_covid']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("Total data shape : ",df.shape)
print("-------------------------------")
print("-------------------------------")
print("Input data shape : ",x.shape)
print("Input data shape : ",x_train.shape)
print("Input data shape : ",x_test.shape)
print("-------------------------------")
print("-------------------------------")
print("Target data shape : ",y.shape)
print("Target data shape : ",y_train.shape)
print("Target data shape : ",y_test.shape)
# Out:
# Total data shape :  (100, 6)
# -------------------------------
# -------------------------------
# Input data shape :  (100, 5)
# Input data shape :  (80, 5)
# Input data shape :  (20, 5)
# -------------------------------
# -------------------------------
# Target data shape :  (100,)
# Target data shape :  (80,)
# Target data shape :  (20,)

# %%
#df(100,6) = x(100,5) + y(100,1)
#x(100,5) = x_train(80,5)+x_test(20,5)
#y(100,1) = y_train(80,1)+y_test(20,1)

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['city']=df['city'].map({"Kolkata":1,"Bangalore":2,"Delhi":3,"Mumbai":4})
df.sample(5)
# Out:
#     age  gender  fever  cough  city has_covid
# 67   65       1   99.0      0     2        No
# 97   20       0  101.0      0     2        No
# 30   15       1  101.0      0     3       Yes
# 79   48       0  103.0      0     1       Yes
# 2    42       1  101.0      0     3        No

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['has_covid']=df['has_covid'].map({"No":0,"Yes":1})
df.sample(5)
# Out:
#     age  gender  fever  cough  city  has_covid
# 53   83       1   98.0      0     3          1
# 60   24       0  102.0      1     2          1
# 54   60       0   99.0      0     4          1
# 7    20       0    NaN      1     4          1
# 40   49       0  102.0      0     3          0
