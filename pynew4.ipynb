# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasodani03/advancepython/blob/main/pynew4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/placement - placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner = df.iloc[:4,:3]     #iloc[row_range , column_range]
top_left_corner
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]      #loc[row_range , column_range]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.ndim       #number of axis
# Out:
# 2

# %%
df.shape
# Out:
# (100, 3)

# %%
df.size
# Out:
# 300

# %%
a=df.values        #get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()        #create a copy in another variable

# %%
p = df.sort_values(by='resume_score')     #sorting in asc/des order by column names
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df.sort_index()
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)     #type conversion
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']=df['resume_score'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']=df['resume_score'].add(5)
df
# Out:
#     cgpa  resume_score  placed
# 0     12            20      11
# 1     10            19      10
# 2     12            22      11
# 3     10            21      11
# 4     11            21      11
# ..   ...           ...     ...
# 95    10            20      10
# 96    12            21      11
# 97    10            21      10
# 98    12            19      11
# 99    10            20      10
#
# [100 rows x 3 columns]

# %%
df['placed']=df['placed'].add(6)
df
# Out:
#     cgpa  resume_score  placed
# 0     12            10      11
# 1     10             9      10
# 2     12            12      11
# 3     10            11      11
# 4     11            11      11
# ..   ...           ...     ...
# 95    10            10      10
# 96    12            11      11
# 97    10            11      10
# 98    12             9      11
# 99    10            10      10
#
# [100 rows x 3 columns]

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
s=df.max()
s
# Out:
# cgpa            13
# resume_score    23
# placed          11
# dtype: int64

# %%
s=df.min()
s
# Out:
# cgpa             9
# resume_score    18
# placed          10
# dtype: int64

# %%
s=df['cgpa'].mean()
s
# Out:
# np.float64(10.47)

# %%
s=df['cgpa'].median()
s
# Out:
# 10.0

# %%
df.median()
# Out:
# cgpa            10.0
# resume_score    21.0
# placed          10.5
# dtype: float64

# %%
g=df.filter(items=['cgpa','resume_score'])    #column wise filter
g
# Out:
#     cgpa  resume_score
# 0     12            20
# 1     10            19
# 2     12            22
# 3     10            21
# 4     11            21
# ..   ...           ...
# 95    10            20
# 96    12            21
# 97    10            21
# 98    12            19
# 99    10            20
#
# [100 rows x 2 columns]

# %%
df[['cgpa','resume_score']]  #2nd method of filtering
# Out:
#     cgpa  resume_score
# 0     12            20
# 1     10            19
# 2     12            22
# 3     10            21
# 4     11            21
# ..   ...           ...
# 95    10            20
# 96    12            21
# 97    10            21
# 98    12            19
# 99    10            20
#
# [100 rows x 2 columns]

# %%
g=df.filter(items=[5,6] , axis=0)    #row wise filter
g
# Out:
#    cgpa  resume_score  placed
# 5    12            20      11
# 6     9            21      10

# %%
s=df.to_dict()      #save in dictionary
s

# %%
s=df.to_string()    #save in string
s
# Out:
# '    cgpa  resume_score  placed\n0     12            20      11\n1     10            19      10\n2     12            22      11\n3     10            21      11\n4     11            21      11\n5     12            20      11\n6      9            21      10\n7     10            20      10\n8     10            20      10\n9     11            21      11\n10    10            20      10\n11     9            20      10\n12    10            21      10\n13    12            19      11\n14    11            20      11\n15    12            19      11\n16    12            21      11\n17    11            22      11\n18     9            19      10\n19    10            22      11\n20     9            22      10\n21    10            21      10\n22    10            19      10\n23    10            21      10\n24    12            20      11\n25    11            19      11\n26    10            20      10\n27     9            20      10\n28    11            21      11\n29    10            21      10\n30   
# ...

# %%
idx=df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
type(idx)
# Out:
# pandas.core.indexes.base.Index

# %%
label=df.columns[0]
label
# Out:
# 'cgpa'

# %%
type(label)
# Out:
# str

# %%
p=df.columns.tolist()     #list of column labels
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q=df.columns.values     #array of column labels
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns={'cgpa':'updated_cgpa','resume_score':'semester_score'})     #how to rename a column
p
# Out:
#     updated_cgpa  semester_score  placed
# 0             12              20      11
# 1             10              19      10
# 2             12              22      11
# 3             10              21      11
# 4             11              21      11
# ..           ...             ...     ...
# 95            10              20      10
# 96            12              21      11
# 97            10              21      10
# 98            12              19      11
# 99            10              20      10
#
# [100 rows x 3 columns]

# %%
df['Cgpa']=df['cgpa'].astype(int)

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0     12            20      11    12
# 1     10            19      10    10
# 2     12            22      11    12
# 3     10            21      11    10
# 4     11            21      11    11
# ..   ...           ...     ...   ...
# 95    10            20      10    10
# 96    12            21      11    12
# 97    10            21      10    10
# 98    12            19      11    12
# 99    10            20      10    10
#
# [100 rows x 4 columns]

# %%
a=df.drop(columns=['Cgpa','placed'])
a
# Out:
#     cgpa  resume_score
# 0     12            20
# 1     10            19
# 2     12            22
# 3     10            21
# 4     11            21
# ..   ...           ...
# 95    10            20
# 96    12            21
# 97    10            21
# 98    12            19
# 99    10            20
#
# [100 rows x 2 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0     12            20      11    12
# 1     10            19      10    10
# 2     12            22      11    12
# 3     10            21      11    10
# 4     11            21      11    11
# ..   ...           ...     ...   ...
# 95    10            20      10    10
# 96    12            21      11    12
# 97    10            21      10    10
# 98    12            19      11    12
# 99    10            20      10    10
#
# [100 rows x 4 columns]

# %%
df=df.drop(columns=['Cgpa'])
df
# Out:
#     cgpa  resume_score  placed
# 0     12            20      11
# 1     10            19      10
# 2     12            22      11
# 3     10            21      11
# 4     11            21      11
# ..   ...           ...     ...
# 95    10            20      10
# 96    12            21      11
# 97    10            21      10
# 98    12            19      11
# 99    10            20      10
#
# [100 rows x 3 columns]

# %%
df['new']=df['cgpa'].where(df['cgpa']>10 , other=0)

# %%
df.sample(10  )
# Out:
#     cgpa  resume_score  placed  new
# 58    10            21      10    0
# 61    10            21      11    0
# 54     9            21      10    0
# 37    13            22      11   13
# 5     12            20      11   12
# 74     9            21      10    0
# 12    10            21      10    0
# 51    10            21      10    0
# 62     9            22      10    0
# 3     10            21      11    0

# %% [markdown]
# **Merging and concatinating**

# %%
data1={
    "name" : ["sally","Mary","John"],
    "age" : [50,40,30]
}

data2={
    "name" : ["sally","Peter","Mickey"],
    "age" : [77 ,44,22]
}

df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

newdf = df1.merge(df2,how='right')
newdf
# Out:
#      name  age
# 0   sally   77
# 1   Peter   44
# 2  Mickey   22

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A','Bcom','B.hons']}

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
new_dt=pd.concat([df1,df2])
new_dt
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons

# %%
df=pd.merge(df1,df2,on='Address',how='inner')
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12            Bcom
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52          B.hons
