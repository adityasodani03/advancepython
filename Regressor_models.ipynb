# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasodani03/advancepython/blob/main/Regressor_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/insurance - insurance.csv')
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df=pd.get_dummies(df,columns=['sex','smoker','region'])
df.head(3)
# Out:
#    age    bmi  children     charges  sex_female  sex_male  smoker_no  \
# 0   19  27.90         0  16884.9240        True     False      False
# 1   18  33.77         1   1725.5523       False      True       True
# 2   28  33.00         3   4449.4620       False      True       True
#
#    smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0        True             False             False             False
# 1       False             False             False              True
# 2       False             False             False              True
#
#    region_southwest
# 0              True
# 1             False
# 2             False

# %%
df=df.astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7837888448800692

# %% [markdown]
# 2. Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.739113825757067

# %% [markdown]
# 3. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8560115340089626

# %% [markdown]
# 4. SVR

# %%
from sklearn.preprocessing import  StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel='rbf')

# %%
svr_model.fit(x_train_scaled, y_train)
# Out:
# SVR()

# %%
svr_pred = svr_model.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,svr_pred)
# Out:
# -0.06896063273604547

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,svr_pred)
# Out:
# 165954446.88429713

# %% [markdown]
# 5. KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=6)

# %%
knn_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
knn_pred = knn_model.predict(x_test_scaled)

# %%
r2_score(y_test, knn_pred)
# Out:
# 0.8021025809674254
