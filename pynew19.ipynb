# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasodani03/advancepython/blob/main/pynew19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Decision Tree Model**

# %% [markdown]
# Decision Tree Regressor

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/insurance - insurance.csv')
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
df=pd.get_dummies(df,columns=['sex','smoker','region'])

# %%
df=df.astype(int)

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.695283634377704

# %% [markdown]
# Decision Tree Classifier

# %%
df=pd.read_csv('/content/Social_Network_Ads - Social_Network_Ads.csv')
df.head(2)
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
df=pd.get_dummies(df,columns=['Gender'])

# %%
df.head(2)
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0  15624510   19            19000          0          False         True
# 1  15810944   35            20000          0          False         True

# %%
x=df.drop(columns=['Purchased'])
y=df['Purchased']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8875
